# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("train_data.csv", index_col=0) # Let's preprocess training data first
# Out:
# C:\Users\vojte\AppData\Local\Temp\ipykernel_8940\197131134.py:1: DtypeWarning: Columns (65,76,91,154,170,171) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("train_data.csv", index_col=0) # Let's preprocess training data first

# %%
len(df.columns) # The data has 171 columns
# Out:
# 171

# %%
df.isna().sum().sort_values(ascending=False)[:10]
# Let's look at the structure of the missing data
# Out:
# LB.2    155066
# LB.1    155063
# LB      155063
# HT      154063
# AT      154056
# HFKC    153867
# AFKC    153867
# SYD     149720
# LBAH    149715
# SYA     149712
# dtype: int64

# %%
important_features = ['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR']
sns.heatmap(df[important_features].isnull()) 
# Looks good, the important features don't have a lot of missing data
# Out:
# <Axes: >

# %%
important_features = ["Attendance", "Referee", "HS", "AS", "HST", "AST", "HHW", "AHW", "HC", "AC"]
sns.heatmap(df[important_features].isnull()) 
# We can see that these features have a lot of missing data
# We will have to impute them, or restrict the dataset
# Out:
# <Axes: >

# %%
important_features = ["HF", "AF", "HFKC", "AFKC", "HO", "AO", "HY", "AY", "HR", "AR", "HBP", "ABP"]
sns.heatmap(df[important_features].isnull())
# Similarly to the last features we looked at, some parameters have a lot of missing values
# In the next step, we will examine, whether these features are in any way important for the target variables
# Out:
# <Axes: >
